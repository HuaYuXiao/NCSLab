# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('/home/hyx020222/NCSLab/PWM/data_PWM2Vout.txt')

x = data[:, 0]
y = data[:, 1]

# %%
coefficients = np.polyfit(x, y, 1)
poly = np.poly1d(coefficients)

# %%
poly
# Out:
# poly1d([ 0.03825091, -0.00272727])

# %%
plt.scatter(x, y)
plt.plot(x, poly(x))

plt.show()
